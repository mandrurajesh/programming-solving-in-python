# %% [markdown]
# ## NOTES
#
# ### DAY OBJECTIVES
#
# 1.*Objective 1
#
# 2.*Objective 2
#
# 3.*Objective 3

# %% [markdown]
# ### Problem 1:
# #### Problem Statement:
#
# ### CONSTRAINTS:
#
# #### Test cases:

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

plt.plot([1,2,3,4],[1,4,9,16])
plt.xlabel('time')
plt.ylabel('distance')
plt.show()

# %%
import pandas as pd
df=pd.read_csv('DataFiles\income.csv')
y=df.values[4]
x=df.columns

# %%
import numpy as np

t = np.arange(0.0,2.0,0.1)
v = 1 + np.sin(2 * np.pi * t)

plt.xlabel('time')
plt.ylabel('distance')
plt.plot(t,v)
plt.savefig('figures/pictures')
plt.show()

# %%
y
x
# Out:
# array([0.72901515, 0.3263465 , 0.64217578, 0.06623494, 0.94626467,
#        0.62689433, 0.67569444, 0.25781126, 0.00886503, 0.31178994,
#        0.31701044, 0.26334692, 0.89571176, 0.97063674, 0.6117765 ,
#        0.75403968, 0.40594669, 0.75219446, 0.81643895, 0.67528044,
#        0.99903995, 0.7350345 , 0.80292455, 0.71361531, 0.44471503,
#        0.96518327, 0.32176746, 0.30411095, 0.0782822 , 0.02967225,
#        0.62142524, 0.55545389, 0.57895976, 0.73924002, 0.64712188,
#        0.70415543, 0.81971579, 0.18156379, 0.16016962, 0.10916119,
#        0.0571541 , 0.7854619 , 0.29473122, 0.54774564, 0.02518858,
#        0.85593195, 0.30839754, 0.30319127, 0.64657567, 0.30957137])

# %%
import pandas as pd
df = pd.read_csv('DataFiles/income.csv')
y= df.values[4]
x = df.columns
years = []
for i in range(2,len(x)):
    years.append(x[i])
years
income = []
for i in range(2,len(y)):
    income.append(y[i])
income
plt.xlabel('year')
plt.ylabel('income')
plt.plot(years,income)
plt.grid(True)
plt.savefig('figures/pictures1')
plt.show()

# %%
width = 1/2
plt.bar(years,income,width,color='red')
plt.savefig('figures/pictures2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-529f2aea44d1> in <module>
#       1 width = 1/2
# ----> 2 plt.bar(years,income,width,color='red')
#       3 plt.savefig('figures/pictures2')
#
# NameError: name 'years' is not defined

# %%
N = 50

x = np.random.rand(N)
y = np.random.rand(N)
colorlist = np.random.rand(N)
arealist = np.pi*(15*np.random.rand(50))**2
plt.scatter(x,y,s=arealist,c=colorlist,alpha=1)
plt.savefig('figures/pictures3')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-702f73b2cc52> in <module>
#       1 N = 50
#       2
# ----> 3 x = np.random.rand(N)
#       4 y = np.random.rand(N)
#       5 colorlist = np.random.rand(N)
#
# NameError: name 'np' is not defined
